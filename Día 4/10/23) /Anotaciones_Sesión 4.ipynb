# %%
lista = ['Hola', 'soy', 'Luis']

# %%
list[1]
# Out:
# list[1]

# %%
diccionario = {0:'Hola', 1:'soy', 2:'Luis', 'persona':'Juan'}

# %%
diccionario['persona']
# Out:
# 'Juan'

# %%
lista_moviles = [6666666, 96598956]

# %%
# Para sacar los números de teléfono de una persona
agenda = {'Luis':lista_moviles, 'Pepe':98989898989, 'Julia':7878787878, 0: 'No tengo número'}

# %%
print(agenda['Luis'])
print(agenda['Luis'][1])
# Out:
# [6666666, 96598956]
# 96598956

# %%
# engine es la conexión a la base de datos (Google Cloud, AWS...)
