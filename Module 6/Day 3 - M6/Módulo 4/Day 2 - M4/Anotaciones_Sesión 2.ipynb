# %%
# ESTADOS DE VARIABLES EN PYTHON

# 1er ESTADO. Indefinido
# No existe, no tipo, no contenido
# patata

# 2º ESTADO NULO
# Sí existe, no tipo, no contenido
patata = None

# 3er ESTADO
# Sí existe, sí tipo, no contenido
patata = []
numero = 0
decimal = 0.0
texto = ''
estado = False

# 4o ESTADO (cualquier valor != 0)
# Sí existe, sí tipo, sí contenido
lista = [1,2,3]
numero = 45
decimales = 0.00001
# Out:
# None

# %%
lista = []

if lista:
  print('Hay algo en la lista')
else:
  print('No hay algo en la lista')
# Out:
# Hay algo en la lista

# %%
lista = [1,2,3,4]

# BUCLES

# FORMA FÁCIL: FOR
for numero in lista:
  print(numero)
# Out:
# 1
# 2
# 3
# 4

# %%
# BUCLES

# FORMA DIFÍCIL: WHILE
posicion = 0
while posicion < len(colores):
  variable_iteradora = colores[posicion]
  posicion = posicion + 1
  print(variable_iteradora)
