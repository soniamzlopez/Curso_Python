# %%
# Variables
# Crear variables
# nombre_variable = dato
numero = 2
decimal = -5.2
verdadero = True
falso = False
texto = "Luis"

# %%
# Usar variables
print(numero)
print(texto)
# Out:
# 2
# Luis

# %%
# Listas
lista = [1, 2, 3, 4, 5, 6]
new_lista = ["Luis", 2, 3, True]

# %%
# Para sacar valores de las listas
new_lista[1]
# Out:
# 2
